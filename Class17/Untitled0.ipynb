# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
  return 4*x**2/(x-0.21)/(x-0.78)


x = np.linspace(0,1)
y = f(x)
plt.plot(x,y)

# %%
def f(x):
  return 4*x**2 - 0.001*(x-0.21)*(x-0.78)


x = np.linspace(0,1)
y = f(x)
plt.plot(x,y)
